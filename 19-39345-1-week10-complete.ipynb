# %% [markdown]
# # N Queen Attack Detection

# %%
import random
N = 4
r = []
c = []
for i in range(1, N+1):
    r1 = random.choice(range(1, N+1))
    c1 = random.choice(range(1, N+1))
    while (r1 in r) and (c1 in c) and (r.index(r1)==c.index(c1)):
        r1 = random.choice(range(1, N+1))
        c1 = random.choice(range(1, N+1))
    r.append(r1)
    c.append(c1)
    print('Q{}: {},{}'.format(i,r[-1],c[-1]))
print(r)
print(c)

# %%
# row attack
for i in range(0,N):
    for j in range(i+1,N):
        if(r[i] == r[j]):
            print('row attack: row:{} column:{} and {}'.format(r[i],c[i],c[j]))

# %%
#column attack
for i in range(0,N):
    for j in range(k+1,N):
        if(c[i] == c[j]):
            print('column attack: column:{} row:{} and {}'.format(c[i],r[i],r[j]))

# %%
# diagonal atack
for i in range(0,N):
    for j in range(i+1,N):
        deltaRow = abs(r[i] -r[j])
        deltaCol = abs(c[i] - c[j])
        if(deltaRow==deltaCol):
            print('Diagonal attack between row:{} column:{} and row:{} column:{}'.format(r[i],c[i],r[j],c[j]))

# %%
##taking input of row and column
### creating an empty list
r = []
c=[]
# number of elemetns as input
n = int(input("Enter number of row and column: "))
 
# iterating till the range
for i in range(0, n):
    row_element = int(input("Enter the value of row: "))
    if(row_element<=n):
        r.append(row_element) # adding the element
    else:
        print('value must be within row range')
for j in range(0, n):
    column_element = int(input("Enter the value of column: "))
    if(column_element<=n):
        c.append(column_element) # adding the element
    else:
        print('value must be within column range')
print('Row:')
print(r)
print('column')
print(c)
def valuecheck(r,c): #method to check the values if they are safe
    deltaRow = abs(r[i] -r[j])
    deltaCol = abs(c[i] - c[j])
    for i in range(0,n):
        for j in range(i+1,n):
            if((r[i] != r[j]),c[i] != c[j], deltaRow!=deltaCol):
                print("position is safe")
                return true
            else:
                if(r[i] == r[j]):
                    print('row attack: row:{} column:{} and {}'.format(r[i],c[i],c[j]))
                else:
                     return false   
                if(c[i] == c[j]):
                    print('column attack: column:{} row:{} and {}'.format(c[i],r[i],r[j]))
                else:
                    return false
                if(deltaRow==deltaCol):
                    print('Diagonal attack between row:{} column:{} and row:{} column:{}'.format(r[i],c[i],r[j],c[j]))
                else:
                    return false
