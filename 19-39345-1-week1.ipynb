# %% [markdown]
# ** name: Zafrin sultana
# ID: 19-39345-1
# Lab week 1 **

# %%
123+122

# %% [markdown]
# **number example**

# %%
a=76
b=78-10
c=a+b
print(c)

# %%
a**2

# %% [markdown]
# string example

# %%
s="human"
len(s)

# %%
s[0]

# %%
s[4]

# %%
s[-1]

# %%
s[0:3]

# %%
s[1:]

# %%
s+'ly'

# %%
s*3

# %%
s+1 #it wil give error

# %%
s.find('man')

# %%
dir(s)

# %%
s.replace('man','cat')

# %%
s.isalpha()

# %%
name='zafrin sultana'
fn, last=name.split(' ')
fn=name.split(' ')[1]
fn

# %%
myname="Zafrin sultana jolly"
myname.split(' ')
fn=myname.split(' ')[0]
ln=myname.split(' ')[-1]
print(fn)
print(ln)

# %% [markdown]
# list examples

# %%
d=[12,'jolly',5.5,'foods']

# %%
d[0]=9
d

# %%
d.append('new')
d

# %%
d.pop(2)

# %%
d.reverse()
d

# %%
d=[12,'jolly',5.5,'foods']
dir(d)

# %%
S='A\nB\tC'
len(S)
ord('\t')

# %% [markdown]
# nesting

# %%
j=[[1,2,3],[4,5,6],[7,8,9]]
j

# %%
j[1][2]

# %% [markdown]
# list comprehensions

# %%
col2=[row[1] for row in j]
col2

# %% [markdown]
# adding 4 to each column no 2

# %%
col=[row[1]+4 for row in j]
col

# %% [markdown]
# filter out even items

# %%
column=[row[1] for row in j if row[1]%2!=0]
column

# %% [markdown]
# diagonal

# %%
diag=[j[i][i] for i in [0,1,2]]
diag

# %% [markdown]
# repeat char

# %%
doubles=[c*2 for c in 'jolly']
doubles

# %% [markdown]
# Mapping operations

# %%
D={'name':'zafrin','class':2,'section':'j'}
D['name']

# %%
D['class']+=1
D

# %% [markdown]
# Nestion revisited

# %%
rec = {'name': {'first': 'zafrin', 'last': 'jolly'},
'job': ['dev', 'mgr'],
'age': 21}
rec['name']

# %%
rec['name']['first']

# %%
rec['job']

# %% [raw]
# rec['job'][-1]

# %%
rec['job'].append('janitor')
rec

# %% [markdown]
# loops

# %%
j={'x':1,'y':3,'z':2}
j

# %%
j={'x':1,'y':3,'z':2}
list(j.keys())

# %%
D={'a': 1, 'c': 3, 'b': 2}
D

# %%
for key in sorted(D):print (key,'=>',D[key])

# %% [markdown]
# Squares

# %%
squares=[x**4 for x in [1,2,3,4,5]]
squares

# %%
squares=[]
for x in [1,2,3,4,5]: squares.append(x**2)
squares

# %%
D

# %%
D['e']=99
dir(D)
'a' in D.keys() #checking is a is available in D

# %% [markdown]
# tuples

# %%
z=(1,2,3,4)
len(z)

# %%
z+(5,6)

# %%
z[0]

# %%
f=open('data.txt','w')
f.write('Zafrin \n ')
f.write('jolly \n')
f.close()

# %%
f=open('data.txt')
bytes=f.read()
bytes

# %%
print (bytes)

# %%
bytes.split()

# %%
dir(f)

# %%
help(f.seek)

# %%
a=set('jolly')
b=set(['j','a','f','r','i','n'])
a,b

# %%
a&b

# %%
a-b

# %%
a | b

# %%
b-a

# %% [markdown]
# addition in decimal

# %%
import decimal
d=decimal.Decimal('9.81')
d+1

# %% [markdown]
# boolean

# %%
3>4,2>1,7<10,4<1

# %%
Q= None
print(Q)

# %%
M=[None]*10
M

# %%
type(M)

# %%
type(type(type(M)))

# %%
type(Q) #shows what type of variable is this . Even types are obj.

# %% [markdown]
# Break codes flexibility

# %%
if(type(M))==type([]):print('correct') #using if

# %%
if type(M)==list: print('yes')

# %%
if isinstance(M,list): print('yeah!') #cheching in oop if its instance

# %% [markdown]
# OOP based task

# %%
class Student : 
    def __init__(self,name,taken_credit) :
        self.name=name
        self.taken_credit=taken_credit
    def stdlastname(self):
        return self.name.split()[-1] 
    def addCredit(self,noOfCourse,labCourse):
        self.taken_credit+=(noOfCourse*3+labCourse*1)
        print(self.taken_credit)

# %%
jolly=Student('Zafrin sultana jolly',12)

# %%
  zerin=Student('Zerin khan',10)

# %%
 rahim=Student('bin ibne rahim ',9)

# %%
jolly.stdlastname()

# %%
zerin.stdlastname()

# %%
jolly.addCredit(2,1)
